# %% [markdown]
# # Mi Primer Notebook de Julia en Binder
# Este es un ejemplo de cómo ejecutar Julia en la nube.

# %%
using Plots

x = 0:0.1:2pi
y = sin.(x)

plot(x, y, title="Gráfico desde Notebook", lw=2)
